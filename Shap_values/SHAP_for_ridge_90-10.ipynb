# %% [markdown]
# This notebook is here as a last minute thing after the error with the jupiter notebook in visual studio that stoped working
#
# For this I need the:
# validation set /beta
# the ridge regression model
# the featue weigths (just in case), please make sure they are in colab folder

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
import shap
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import f1_score
import pickle

# %%
shap.__version__
# Out:
# '0.46.0'

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.metrics import matthews_corrcoef, confusion_matrix

# %%
ridge_model = pickle.load(open('ridge_model_smote.pkl', 'rb'))
ridge_model = pickle.load(open(f'/home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/Results/master/models/RNAs_z_Combat_7_SMOTE_seq_regressor_556i_10_RIDGE.pkl', 'rb'))

# %%
test_file="RNAseq_Combat_z_score_Test_set.csv"

# %%
test_data = pd.read_csv(test_file)
test_data.columns
# Out:
# Index(['ENSG00000000003.14', 'ENSG00000000005.5', 'ENSG00000000419.12',
#        'ENSG00000000457.13', 'ENSG00000000460.16', 'ENSG00000000938.12',
#        'ENSG00000000971.15', 'ENSG00000001036.13', 'ENSG00000001084.11',
#        'ENSG00000001167.14',
#        ...
#        'ENSG00000285491.1', 'ENSG00000285505.1', 'ENSG00000285508.1',
#        'ENSG00000285509.1', 'Age', 'Status', 'Experiment', 'Age.1', 'Sample',
#        'Sex'],
#       dtype='object', length=34511)

# %%
# prompt: remove NAN in X_test_data

import pandas as pd
import numpy as np

# ... (your existing code)

test_data = test_data.fillna(0) # Replace NaN values with 0
# or
# X_test_data = X_test_data.dropna() # Remove rows with NaN values
# or other methods to handle NaN values depending on the context

# ... (rest of your code)

# %%
test_data.drop(columns=["Age.1"], inplace=True)
X_test_data = test_data[test_data.columns[:-5]]
z_test_data = test_data[test_data.columns[-4:]]
y_test_data = test_data["Age"]
z_test_data = z_test_data["Experiment"]

# %%
# prompt: Create a dataframe that has the columns Age, Experiment and the Sample as index using test_data

# Create the DataFrame
df= pd.DataFrame({'Age': y_test_data, 'Experiment': z_test_data})
df = df.set_index(pd.Index(range(len(df)))) #Setting the sample as index

df
# Out:
#       Age Experiment
# 0    24.0  GSE157585
# 1    18.0  GSE167186
# 2    23.0  GSE167186
# 3    26.4   GSE60590
# 4    71.0  GSE157585
# ..    ...        ...
# 103  71.0  GSE157585
# 104  23.0  GSE167186
# 105  72.0  GSE164471
# 106  71.0  GSE157585
# 107  71.0  GSE167186
#
# [108 rows x 2 columns]

# %%
X_test_data
# Out:
#      ENSG00000000003.14  ENSG00000000005.5  ENSG00000000419.12  \
# 0             -0.022233          -0.024446           -0.006216
# 1             -0.023307          -0.025360           -0.006206
# 2             -0.027950          -0.030171           -0.006227
# 3             -0.024681          -0.028953           -0.002464
# 4             -0.021846          -0.026700            0.003155
# ..                  ...                ...                 ...
# 103           -0.025402          -0.027702           -0.001319
# 104           -0.020350          -0.026256           -0.006269
# 105           -0.023877          -0.028292           -0.003818
# 106           -0.025112          -0.029562            0.000282
# 107           -0.025679          -0.025916           -0.002175
#
#      ENSG00000000457.13  ENSG00000000460.16  ENSG00000000938.12  \
# 0             -0.024515           -0.023171           -0.023202
# 1             -0.022286           -0.022653           -0.024454
# 2             -0.026315           -0.025683           -0.028757
# 3             -0.027633           -0.027815           -0.027149
# 4             -0.022868           -0.023732           -0.026121
# ..                  ...                 ...                 ...
# 103           -0.025818           -0.025609           -0.027285
# 104           -0.023194           -0.023090           -0.025255
# 105           -0.026749           -0.026163           -0.027351
# 106           -0.026724           -0.027813           -0.029708
# 107           -0.024273           -0.024195           -0.025532
#
#      ENSG00000000971.15  ENSG00000001036.13  ENSG00000001084.11  \
# 0             -0.019452           -0.021846           -0.022867
# 1             -0.018532           -0.020077           -0.018804
# 2             -0.020073           -0.022860           -0.020748
# 3             -0.019945           -0.025554           -0.020408
# 4             -0.013602           -0.018935           -0.015076
# ..                  ...                 ...                 ...
# 103           -0.023140           -0.022924           -0.020265
# 104           -0.018721           -0.020525           -0.019203
# 105           -0.020208           -0.023042           -0.024271
# 106           -0.013082           -0.021109           -0.021883
# 107           -0.019581           -0.018777           -0.019614
#
#      ENSG00000001167.14  ...  ENSG00000285458.1  ENSG00000285470.1  \
# 0             -0.023905  ...          -0.021222          -0.024522
# 1             -0.020995  ...          -0.020113          -0.025321
# 2             -0.024276  ...          -0.022675          -0.030003
# 3             -0.027101  ...          -0.025233          -0.028767
# 4             -0.019944  ...          -0.020558          -0.026779
# ..                  ...  ...                ...                ...
# 103           -0.024281  ...          -0.023543          -0.027779
# 104           -0.021669  ...          -0.020478          -0.026193
# 105           -0.025981  ...          -0.020212          -0.028309
# 106           -0.024146  ...          -0.025092          -0.030153
# 107           -0.023508  ...          -0.019850          -0.025943
#
#      ENSG00000285471.1  ENSG00000285472.1  ENSG00000285476.1  \
# 0            -0.024480          -0.024511          -0.024499
# 1            -0.025120          -0.025282          -0.025088
# 2            -0.029834          -0.029983          -0.029799
# 3            -0.029022          -0.028779          -0.028634
# 4            -0.026721          -0.026766          -0.026488
# ..                 ...                ...                ...
# 103          -0.027220          -0.027766          -0.026714
# 104          -0.025998          -0.026158          -0.025965
# 105          -0.028245          -0.028309          -0.028252
# 106          -0.030124          -0.030141          -0.029958
# 107          -0.025794          -0.025918          -0.025847
#
#      ENSG00000285480.1  ENSG00000285491.1  ENSG00000285505.1  \
# 0            -0.023623          -0.024472          -0.024526
# 1            -0.024710          -0.025252          -0.025311
# 2            -0.029041          -0.029934          -0.029985
# 3            -0.026764          -0.028774          -0.028772
# 4            -0.026991          -0.026722          -0.026784
# ..                 ...                ...                ...
# 103          -0.024396          -0.027726          -0.027783
# 104          -0.025516          -0.026124          -0.026181
# 105          -0.027582          -0.028327          -0.028302
# 106          -0.029177          -0.030107          -0.030156
# 107          -0.023161          -0.025918          -0.025949
#
#      ENSG00000285508.1  ENSG00000285509.1
# 0            -0.023199          -0.024432
# 1            -0.024447          -0.025087
# 2            -0.022886          -0.029776
# 3            -0.027571          -0.028812
# 4            -0.025465          -0.026577
# ..                 ...                ...
# 103          -0.026468          -0.027604
# 104          -0.018528          -0.025961
# 105          -0.027453          -0.027923
# 106          -0.028848          -0.029939
# 107          -0.018476          -0.025756
#
# [108 rows x 34505 columns]

# %%
y_pred = ridge_model.predict(X_test_data)
y_pred
# Out:
# array([26.23692072, 22.08968977, 22.62496626, 38.91759509, 82.49895654,
#        25.4220096 , 68.21666642, 30.0411182 , 18.83910632, 78.35442398,
#        54.58455425, 69.05391487, 76.46358155, 50.04007551, 78.94195828,
#        66.29454896, 69.95019991, 61.60756554, 60.60383772, 22.41595113,
#        21.32813519, 65.07789978, 85.15376686, 56.24337731, 29.65174408,
#        68.30487838, 78.40318692, 27.67813357, 61.85998347, 28.25034742,
#        40.42067145, 17.58760558, 57.26229663, 23.33679426, 72.80301089,
#        47.31504896, 73.74005026, 44.98510501, 80.46137325, 25.96554163,
#        69.71396566, 20.9819421 , 70.42023505, 70.42510258, 97.36808144,
#        40.4665686 , 78.00463656, 30.18074541, 74.16985619, 46.96579265,
#        66.72880173, 72.82149041, 43.21312896, 82.59334217, 71.9749651 ,
#        36.76692418, 68.47604006, 60.07894759, 49.70490783, 53.07260573,
#        75.80691364, 66.99510663, 74.09332809, 74.26461832, 22.77363692,
#        53.90322676, 25.6116818 , 70.18022645, 14.31713034, 27.40550704,
#        14.17277956, 62.08862747, 31.86751531, 72.26701401, 32.83173162,
#        88.3047685 , 19.54809277, 76.9580905 , 41.43280305, 32.12442037,
#        70.42878428, 32.40824268, 24.63229877, 28.34477273, 52.82433658,
#        61.89912192, 51.68451438, 71.78536935, 73.24735343, 73.24081638,
#        67.41536657, 91.70633136, 91.04156164, 69.85418208, 75.57611293,
#        19.69886243, 59.01786482, 78.57920242, 56.41090762, 31.27993851,
#        27.88022986, 82.29611349, 64.96704393, 71.7111139 , 23.14748599,
#        64.71772855, 67.07338006, 74.51743212])

# %%
# Calculate evaluation metrics
mse = mean_squared_error(y_test_data, y_pred)
rmse = mean_squared_error(y_test_data, y_pred)#, squared=False)  # Calculate RMSE from MSE
mae = mean_absolute_error(y_test_data, y_pred)
r2 = r2_score(y_test_data, y_pred)


result_metrics = {"Method": "Ridge Regression",  "MSE": mse, "RMSE": rmse, "MAE": mae, "R2": r2}


results = pd.DataFrame({'Actual': y_test_data, 'Predicted': y_pred, 'Group': z_test_data})

# %%
results
# Out:
#      Actual  Predicted      Group
# 0      24.0  26.236921  GSE157585
# 1      18.0  22.089690  GSE167186
# 2      23.0  22.624966  GSE167186
# 3      26.4  38.917595   GSE60590
# 4      71.0  82.498957  GSE157585
# ..      ...        ...        ...
# 103    71.0  71.711114  GSE157585
# 104    23.0  23.147486  GSE167186
# 105    72.0  64.717729  GSE164471
# 106    71.0  67.073380  GSE157585
# 107    71.0  74.517432  GSE167186
#
# [108 rows x 3 columns]

# %%
#results.to_csv("results_validation_untoached_Ridge.csv", index=False)

# %%
# !pip install pybiomart
# !pip install scanpy
# Out:
# Requirement already satisfied: pybiomart in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: future in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from pybiomart) (1.0.0)
# Requirement already satisfied: pandas in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from pybiomart) (2.2.3)
# Requirement already satisfied: requests in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from pybiomart) (2.31.0)
# Requirement already satisfied: requests-cache in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from pybiomart) (1.2.1)
# Requirement already satisfied: numpy>=1.23.2 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from pandas->pybiomart) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from pandas->pybiomart) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from pandas->pybiomart) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from pandas->pybiomart) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from requests->pybiomart) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from requests->pybiomart) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from requests->pybiomart) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from requests->pybiomart) (2024.2.2)
# Requirement already satisfied: attrs>=21.2 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from requests-cache->pybiomart) (24.2.0)
# Requirement already satisfied: cattrs>=22.2 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from requests-cache->pybiomart) (24.1.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from requests-cache->pybiomart) (4.2.0)
# Requirement already satisfied: url-normalize>=1.4 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from requests-cache->pybiomart) (1.4.3)
# Requirement already satisfied: six>=1.5 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->pybiomart) (1.16.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: scanpy in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (1.10.4)
# Requirement already satisfied: anndata>=0.8 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (0.11.3)
# Requirement already satisfied: h5py>=3.6 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (3.10.0)
# Requirement already satisfied: joblib in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (1.3.2)
# Requirement already satisfied: legacy-api-wrap>=1.4 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (1.4.1)
# Requirement already satisfied: matplotlib>=3.6 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (3.8.3)
# Requirement already satisfied: natsort in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.7 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (3.4.2)
# Requirement already satisfied: numba>=0.56 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (0.60.0)
# Requirement already satisfied: numpy>=1.23 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (1.26.4)
# Requirement already satisfied: packaging>=21.3 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (23.2)
# Requirement already satisfied: pandas>=1.5 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (2.2.3)
# Requirement already satisfied: patsy!=1.0.0 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (0.5.6)
# Requirement already satisfied: pynndescent>=0.5 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (0.5.13)
# Requirement already satisfied: scikit-learn>=1.1 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (1.4.1.post1)
# Requirement already satisfied: scipy>=1.8 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (1.12.0)
# Requirement already satisfied: seaborn>=0.13 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (0.13.2)
# Requirement already satisfied: session-info in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (1.0.0)
# Requirement already satisfied: statsmodels>=0.13 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (0.14.1)
# Requirement already satisfied: tqdm in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (4.67.1)
# Requirement already satisfied: umap-learn!=0.5.0,>=0.5 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scanpy) (0.5.7)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from anndata>=0.8->scanpy) (1.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from matplotlib>=3.6->scanpy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from matplotlib>=3.6->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from matplotlib>=3.6->scanpy) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from matplotlib>=3.6->scanpy) (1.4.5)
# Requirement already satisfied: pillow>=8 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from matplotlib>=3.6->scanpy) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from matplotlib>=3.6->scanpy) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from matplotlib>=3.6->scanpy) (2.8.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from numba>=0.56->scanpy) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from pandas>=1.5->scanpy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from pandas>=1.5->scanpy) (2024.1)
# Requirement already satisfied: six in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from patsy!=1.0.0->scanpy) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from scikit-learn>=1.1->scanpy) (3.3.0)
# Requirement already satisfied: stdlib_list in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from session-info->scanpy) (0.11.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install decoupler
# Out:
# Requirement already satisfied: decoupler in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: numba<0.61.0,>=0.60.0 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from decoupler) (0.60.0)
# Requirement already satisfied: numpy<2,>=1 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from decoupler) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=2.2.2 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from decoupler) (2.2.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.4 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from decoupler) (4.67.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.12.2 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from decoupler) (4.12.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from numba<0.61.0,>=0.60.0->decoupler) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from pandas<3.0.0,>=2.2.2->decoupler) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from pandas<3.0.0,>=2.2.2->decoupler) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from pandas<3.0.0,>=2.2.2->decoupler) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.2.2->decoupler) (1.16.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
from convert_ensembl_2_symbol import convert_to_symbol, filter_nameless_genes

# %%
from anndata import AnnData
import scanpy as sc

# %%
# prompt: save annot in pkl

import pickle

# ... (your existing code)

# Save the 'annot' DataFrame to a pickle file
#annot.to_pickle("annot.pkl")

# Load the annot Dataframe from picke
annot = pd.read_pickle("annot.pkl")

# %%
ensebl_names = X_test_data.columns
ensebl_names = filter_nameless_genes(ensebl_names, annot)
symbol_names = convert_to_symbol(ensebl_names, annot)

# %%
# prompt: take the X_test_data columns, if the value of .split(".")[0] is in ensebl_names, get the same index on ensebl_names but in symbol_names

# Assuming 'ensebl_names' and 'symbol_names' are lists of the same length
# and that the indices in the lists correspond correctly.

# Create a mapping from Ensembl IDs to gene symbols
ensembl_to_symbol = dict(zip(ensebl_names, symbol_names))

# if symbol_name is nan or variant, replace with the same ensebl_name
for key, value in ensembl_to_symbol.items():
    if pd.isna(value) or value =="nan" or value is None:
        ensembl_to_symbol[key] = key

#if X_test_data.colum is not in ensembl_to_symbol, add it with value the same as the key
for col in X_test_data.columns:
    if col not in ensembl_to_symbol:
        ensembl_to_symbol[col] = col
# Initialize an empty list to store the gene symbols for X_test_data columns
selected_symbols = []


# Iterate over columns in X_test_data
for ensembl_id in X_test_data.columns:
    if ensembl_id in ensembl_to_symbol:
        selected_symbols.append(ensembl_to_symbol[ensembl_id])
    else:
        # Handle cases where the Ensembl ID is not found in the mapping.
        # For example, append the original column name or a placeholder
        selected_symbols.append(ensembl_id) # Or selected_symbols.append("Not Found")

# Now 'selected_symbols' contains the corresponding gene symbols for the columns
# in X_test_data, or the original column name if the ensembl ID was not found.

# %%
selected_symbols[:10]
# Out:
# ['TSPAN6',
#  'TNMD',
#  'DPM1',
#  'SCYL3',
#  'FIRRM',
#  'FGR',
#  'CFH',
#  'FUCA2',
#  'GCLC',
#  'NFYA']

# %%
X_test_data.columns = selected_symbols
X_test_data.head()
# Out:
#      TSPAN6      TNMD      DPM1     SCYL3     FIRRM       FGR       CFH  \
# 0 -0.022233 -0.024446 -0.006216 -0.024515 -0.023171 -0.023202 -0.019452
# 1 -0.023307 -0.025360 -0.006206 -0.022286 -0.022653 -0.024454 -0.018532
# 2 -0.027950 -0.030171 -0.006227 -0.026315 -0.025683 -0.028757 -0.020073
# 3 -0.024681 -0.028953 -0.002464 -0.027633 -0.027815 -0.027149 -0.019945
# 4 -0.021846 -0.026700  0.003155 -0.022868 -0.023732 -0.026121 -0.013602
#
#       FUCA2      GCLC      NFYA  ...   C4orf36   TUSC2P1  ENSG00000285471.1  \
# 0 -0.021846 -0.022867 -0.023905  ... -0.021222 -0.024522          -0.024480
# 1 -0.020077 -0.018804 -0.020995  ... -0.020113 -0.025321          -0.025120
# 2 -0.022860 -0.020748 -0.024276  ... -0.022675 -0.030003          -0.029834
# 3 -0.025554 -0.020408 -0.027101  ... -0.025233 -0.028767          -0.029022
# 4 -0.018935 -0.015076 -0.019944  ... -0.020558 -0.026779          -0.026721
#
#    OR4M2-OT1  ENSG00000285476.1     H2BK1   OR1Q1BP  ENSG00000285505.1  \
# 0  -0.024511          -0.024499 -0.023623 -0.024472          -0.024526
# 1  -0.025282          -0.025088 -0.024710 -0.025252          -0.025311
# 2  -0.029983          -0.029799 -0.029041 -0.029934          -0.029985
# 3  -0.028779          -0.028634 -0.026764 -0.028774          -0.028772
# 4  -0.026766          -0.026488 -0.026991 -0.026722          -0.026784
#
#    ENSG00000285508.1  TBCEL-TECTA
# 0          -0.023199    -0.024432
# 1          -0.024447    -0.025087
# 2          -0.022886    -0.029776
# 3          -0.027571    -0.028812
# 4          -0.025465    -0.026577
#
# [5 rows x 34505 columns]

# %%
# Assuming X_test_data is your feature matrix for the test set
explainer = shap.Explainer(ridge_model, X_test_data)
shap_values = explainer(X_test_data)

# You can now access and visualize the SHAP values
# shap.plots.beeswarm(shap_values)  # Bee swarm plot
# shap.plots.bar(shap_values) # Bar plot
# shap.summary_plot(shap_values, X_test_data) # Summary plot

# To get SHAP values for a specific instance:
# shap_values[0]  # SHAP values for the first instance in X_test_data

# To get the base value (expected value):
# explainer.expected_value

# %%
# prompt: Save the SHAP value for each gene

# Assuming X_test_data is your feature matrix for the test set
# and shap_values are already calculated as in your provided code.

# Create a DataFrame to store SHAP values for each gene
shap_df = pd.DataFrame(shap_values.values, columns=X_test_data.columns)
shap_df
# Save the DataFrame to a CSV file
shap_df.to_csv("shap_values_by_gene_Ridge_10_extended.csv", index=False)

# %%
shap_df['MYL2']
# Out:
# 0      -4.099043
# 1     -12.278001
# 2     -12.880726
# 3       3.326947
# 4      10.586987
#          ...
# 103    12.932345
# 104   -11.226998
# 105    -0.126002
# 106    11.759506
# 107     3.673534
# Name: MYL2, Length: 108, dtype: float64

# %%
results.head()
results['Difference'] = results['Actual'] - results['Predicted']

# %%
# @title Group vs Difference

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(results['Group'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(results, x='Difference', y='Group', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
plt.savefig("Group_vs_Difference_Ridge_10_extended.svg",bbox_inches='tight')

# %%
# @title Group

from matplotlib import pyplot as plt
import seaborn as sns
results.groupby('Group').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.savefig("Group_Ridge_10_extended.svg", bbox_inches='tight')

# %%
# prompt: Using dataframe results: calculate per group, what is the average absolute difference between predicted and Actual

# Calculate the absolute difference between predicted and actual values
results['Difference'] = abs(results['Predicted'] - results['Actual'])

# Group by 'Group' and calculate the average absolute difference
average_difference_by_group = results.groupby('Group')['Difference'].mean()

# Display the result
average_difference_by_group
# Out:
# Group
# GSE129643     9.879993
# GSE152558    29.796602
# GSE157585     5.030312
# GSE164471    10.381234
# GSE167186     5.678292
# GSE60590      6.626139
# Name: Difference, dtype: float64

# %%
results[results["Group"]=="GSE152558"]
# Out:
#     Actual  Predicted      Group  Difference
# 10    46.0  61.685428  GSE152558   15.685428
# 37    41.0  19.835898  GSE152558   21.164102
# 59    83.0  30.459724  GSE152558   52.540276

# %%
with open('shap_values_ridge.pkl', 'wb') as f:
    pickle.dump(shap_values, f)

# %%
index=2
title = f"Sample {index}/ {len(shap_values)} \n Age: {y_test_data[index]} \n Experiment: {z_test_data[index]}"
print(title)
shap.plots.waterfall(shap_values[index])
plt.savefig(f"shap_RIDGE_waterfall_{index}.svg", bbox_inches='tight')
# Out:
# Sample 2/ 108
#  Age: 23.0
#  Experiment: GSE167186

# %%
# prompt: Run the shap.summary_plot

plot_shap =shap.summary_plot(shap_values, X_test_data, max_display=10)

# %%
# prompt: save the shap figure

import matplotlib.pyplot as plt

shap.summary_plot(shap_values, X_test_data, max_display=10, show=False)
plt.savefig('summary_plot_Ridge_10.svg', bbox_inches='tight')

# %% [markdown]
# Let's try to get by gene the shap value

# %%
feature_name = "MYL2"  # Replace with the feature of interest
feature_index = X_test_data.columns.get_loc(feature_name)  # Get the column index for the feature

# %%
explainer.expected_value
# Out:
# 54.52061086727236

# %%
list(X_test_data[feature_name].values )
# Out:
# [9.806431421867842,
#  7.57949877648002,
#  7.415391189879538,
#  11.828349049380078,
#  13.805082365677166,
#  10.396184449153042,
#  13.05991192931685,
#  10.059357948472895,
#  7.74670982418295,
#  12.087242480105358,
#  8.38171959720302,
#  11.933317375585748,
#  11.913579268964778,
#  8.914825815380947,
#  11.741703729120722,
#  13.58114696602308,
#  11.345386963458914,
#  9.330469513939793,
#  10.272380812107402,
#  8.560598395752793,
#  7.789042708104835,
#  16.373402631917248,
#  13.352699419962368,
#  9.35810294660634,
#  12.14920410280708,
#  13.433216269823877,
#  14.949658018172114,
#  9.93323788153046,
#  10.870793337591332,
#  7.239598302240524,
#  8.169216762596019,
#  7.60265166188664,
#  11.193344903049956,
#  7.558496430715308,
#  12.241778220293464,
#  9.328621620231186,
#  14.243158777300662,
#  8.163173947352076,
#  10.254013253953836,
#  7.157097388972243,
#  11.77717207095493,
#  8.143443432499177,
#  13.452505031175184,
#  10.754567599358843,
#  14.13337254273125,
#  10.782936261219753,
#  15.224955672017437,
#  10.642099523292572,
#  14.887299374768087,
#  10.556466636819817,
#  11.381529495632144,
#  11.438296156989011,
#  9.829498828427544,
#  10.29718923601215,
#  11.68845813348338,
#  7.082161881801325,
#  13.505557622556887,
#  10.831610185914965,
#  9.689076251763224,
#  11.3052418901827,
#  11.723556135503967,
#  11.780681474715548,
#  12.661266795539028,
#  19.623802999828563,
#  7.976777462203719,
#  9.07674644878491,
#  7.767307392661254,
#  12.359375136547566,
#  6.518036580840412,
#  11.636532408050217,
#  8.085264512787317,
#  12.963899299370317,
#  9.05524086221494,
#  17.595881728644233,
#  11.370699718057567,
#  12.340400844695331,
#  9.4771051550759,
#  12.217515964541873,
#  9.609548094859202,
#  8.96109967129986,
#  13.251507983274127,
#  7.250219756474342,
#  8.217949752359033,
#  11.857175209086591,
#  9.986397134557553,
#  10.2509305173446,
#  9.339145780670425,
#  15.345499834012436,
#  10.119147859759824,
#  12.244449144921369,
#  13.800128481560243,
#  10.007051709177778,
#  12.840340032504978,
#  13.183216667598542,
#  12.112422666078713,
#  8.077910065754931,
#  10.758765384000686,
#  12.335977339022303,
#  9.300064882530382,
#  11.455619645291716,
#  8.96488390613302,
#  12.088158786751446,
#  12.189766912066869,
#  14.443666779376716,
#  7.865661526812063,
#  10.888194316327311,
#  14.12433106575002,
#  11.922716060899916]

# %%
# Generate the force plot for the feature
shap.force_plot(
    explainer.expected_value,  # Expected value for the model
    shap_values.values[:, feature_index],  # SHAP values for the specific feature
    X_test_data[feature_name].values  # Feature values for all samples
)
# Out:
# <div id='iDXHYOZ05GD18036Z7ENY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 54.52061086727236, "outValue": 76.24524654750734, "link": "identity", "featureNames": [9.806431421867842, 7.57949877648002, 7.415391189879538, 11.828349049380078, 13.805082365677166, 10.396184449153042, 13.05991192931685, 10.059357948472895, 7.74670982418295, 12.087242480105358, 8.38171959720302, 11.933317375585748, 11.913579268964778, 8.914825815380947, 11.741703729120722, 13.58114696602308, 11.345386963458914, 9.330469513939793, 10.272380812107402, 8.560598395752793, 7.789042708104835, 16.373402631917248, 13.352699419962368, 9.35810294660634, 12.14920410280708, 13.433216269823877, 14.949658018172114, 9.93323788153046, 10.870793337591332, 7.239598302240524, 8.169216762596019, 7.60265166188664, 11.193344903049956, 7.558496430715308, 12.241778220293464, 9.328621620231186, 14.243158777300662, 8.163173947352076, 10.254013253953836, 7.157097388972243, 11.77717207095493, 8.143443432499177, 13.452505031175184, 10.754567599358843, 14.13337254273125, 10.782936261219753, 15.224955672017437, 10.642099523292572, 14.887299374768087, 10.556466636819817, 11.381529495632144, 11.438296156989011, 9.829498828427544, 10.29718923601215, 11.68845813348338, 7.082161881801325, 13.505557622556887, 10.831610185914965, 9.689076251763224, 11.3052418901827, 11.723556135503967, 11.780681474715548, 12.661266795539028, 19.623802999828563, 7.976777462203719, 9.07674644878491, 7.767307392661254, 12.359375136547566, 6.518036580840412, 11.636532408050217, 8.085264512787317, 12.963899299370317, 9.05524086221494, 17.595881728644233, 11.370699718057567, 12.340400844695331, 9.4771051550759, 12.217515964541873, 9.609548094859202, 8.96109967129986, 13.251507983274127, 7.250219756474342, 8.217949752359033, 11.857175209086591, 9.986397134557553, 10.2509305173446, 9.339145780670425, 15.345499834012436, 10.119147859759824, 12.244449144921369, 13.800128481560243, 10.007051709177778, 12.840340032504978, 13.183216667598542, 12.112422666078713, 8.077910065754931, 10.758765384000686, 12.335977339022303, 9.300064882530382, 11.455619645291716, 8.96488390613302, 12.088158786751446, 12.189766912066869, 14.443666779376716, 7.865661526812063, 10.888194316327311, 14.12433106575002, 11.922716060899916], "features": {"0": {"effect": -4.0990425977920815, "value": ""}, "1": {"effect": -12.278000777947602, "value": ""}, "2": {"effect": -12.88072627601395, "value": ""}, "3": {"effect": 3.3269474757702384, "value": ""}, "4": {"effect": 10.586987046701406, "value": ""}, "5": {"effect": -1.9330294690269145, "value": ""}, "6": {"effect": 7.850165235452661, "value": ""}, "7": {"effect": -3.1701076845430722, "value": ""}, "8": {"effect": -11.663877055232096, "value": ""}, "9": {"effect": 4.277797312834033, "value": ""}, "10": {"effect": -9.33164739023623, "value": ""}, "11": {"effect": 3.7124694860812344, "value": ""}, "12": {"effect": 3.6399764320399655, "value": ""}, "13": {"effect": -7.373683608489795, "value": ""}, "14": {"effect": 3.008721214021744, "value": ""}, "15": {"effect": 9.764529181790001, "value": ""}, "16": {"effect": 1.5531503600240817, "value": ""}, "17": {"effect": -5.847129837140355, "value": ""}, "18": {"effect": -2.3877287936987206, "value": ""}, "19": {"effect": -8.67467098114494, "value": ""}, "20": {"effect": -11.50839912106127, "value": ""}, "21": {"effect": 20.019775278680143, "value": ""}, "22": {"effect": 8.925499348777551, "value": ""}, "23": {"effect": -5.745639255185876, "value": ""}, "24": {"effect": 4.505366620734541, "value": ""}, "25": {"effect": 9.22121729479583, "value": ""}, "26": {"effect": 14.790722806365613, "value": ""}, "27": {"effect": -3.633314668075776, "value": ""}, "28": {"effect": -0.18991152672792308, "value": ""}, "29": {"effect": -13.526368917854105, "value": ""}, "30": {"effect": -10.112116346499828, "value": ""}, "31": {"effect": -12.192966108451477, "value": ""}, "32": {"effect": 0.9947384761779138, "value": ""}, "33": {"effect": -12.355137061368 ...

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
shap.dependence_plot("MYL2", shap_values.values, X_test_data)

# %%
shap.decision_plot(explainer.expected_value, shap_values.values, X_test_data)

# %%
# get the list of the columns of X_test_data with their corresponding average value of their shap_values.values
import sys
sys.path.append('/home/karen/Documents/GitHub/Identify_muscle_age_genes/deep_learning')
import getting_threshold_genes as gtg

shap_avg_values = pd.DataFrame({
    'Feature': X_test_data.columns,
    'Average SHAP Value': np.mean(shap_values.values, axis=0)
})
shap_avg_values["abs_coef"] = shap_avg_values["Average SHAP Value"].abs()


elbow_point = gtg.get_elbow_point_from_gene_rank(shap_avg_values)
threshold_genes = shap_avg_values[shap_avg_values["abs_coef"] > elbow_point]
threshold_genes.sort_values(by="abs_coef", ascending=False, inplace=True)
threshold_genes.to_csv("threshold_genes_Ridge_10_extended.csv", index=False)
len(threshold_genes)
# Out:
# 168

# %%
import pathway_analysis as pa

# %%
df_pathay_analysis = pa.get_pathways('def_expressed.csv', sel_databases_names="all", cutoff=0.05, remove_version_=True)
# Out:
# Error Warning: No enrich terms when cutoff = 0.05
# Error Warning: No enrich terms when cutoff = 0.05
# Error Warning: No enrich terms when cutoff = 0.05
# Error Warning: No enrich terms when cutoff = 0.05
# Error Warning: No enrich terms when cutoff = 0.05
# Error Warning: No enrich terms when cutoff = 0.05
# Error Warning: No enrich terms when cutoff = 0.05
# Error Warning: No enrich terms when cutoff = 0.05
# Error Warning: No enrich terms when cutoff = 0.05
# Error Warning: No enrich terms when cutoff = 0.05
# Error Warning: No enrich terms when cutoff = 0.05
# Error Warning: No enrich terms when cutoff = 0.05
# Error Warning: No enrich terms when cutoff = 0.05
# Error Warning: No enrich terms when cutoff = 0.05
# Error Warning: No enrich terms when cutoff = 0.05
# Error Warning: No enrich terms when cutoff = 0.05
# Error Warning: No enrich terms when cutoff = 0.05
# Error Warning: No enrich terms when cutoff = 0.05
# Error Warning: No enrich terms when cutoff = 0.05
# ...

# %%
df_pathay_analysis
# Out:
# Empty DataFrame
# Columns: [Experiment]
# Index: []
